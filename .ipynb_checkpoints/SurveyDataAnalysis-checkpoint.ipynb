# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("UM_Survey_Data.csv")
# Out:
#    {"ImportId":"startDate","timeZone":"America/Denver"}  \
# 0                                           StartDate
# 1                                          Start Date
# 2                                       11/2/21 15:52
# 3                                       11/2/21 17:26
# 4                                       11/2/21 17:30
# ..                                                ...
# 77                                      11/2/21 16:31
# 78                                      11/2/21 16:33
# 79                                      11/2/21 17:06
# 80                                      11/2/21 17:10
# 81                                      11/2/21 17:16
#
#    {"ImportId":"endDate","timeZone":"America/Denver"} {"ImportId":"duration"}  \
# 0                                             EndDate   Duration (in seconds)
# 1                                            End Date   Duration (in seconds)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-18d17413257d> in <module>
# ----> 1 pd.read_csv("YCOM_2020_Data.csv")
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# ...
