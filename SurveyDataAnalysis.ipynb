# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("YCOM_2020_Data.csv")
# Source US Bureau of Economic Analysis
income = pd.read_csv("income_data_cleaned.csv")
#
df.head()
income.head(20)
# Out:
#          Location 2018_Per_capita_personal_income_in_dollars  \
# 0   United States                                     54,098
# 1         Alabama                                     42,328
# 2         Autauga                                     42,931
# 3         Baldwin                                     46,905
# 4         Barbour                                     34,064
# 5            Bibb                                     30,250
# 6          Blount                                     35,905
# 7         Bullock                                     26,841
# 8          Butler                                     35,932
# 9         Calhoun                                     36,482
# 10       Chambers                                     34,055
# 11       Cherokee                                     35,647
# 12        Chilton                                     34,982
# 13        Choctaw                                     38,200
# 14         Clarke                                     35,437
# 15           Clay                                     33,131
# 16       Cleburne                                     35,668
# 17         Coffee                                     42,176
# 18        Colbert                                     37,601
# 19        Conecuh                                     32,588
#
#    2019_Per_capita_personal_income_in_dollars  \
# 0                                      56,047
# 1                                      43,996
# 2                                      44,368
# 3                                      48,270
# 4                                      35,572
# 5                                      31,540
# 6                                      36,969
# 7                                      28,136
# 8                                      38,073
# 9                                      37,708
# 10                                     36,110
# 11                                     36,381
# 12                                     36,471
# 13                                     39,097
# 14                                     37,061
# 15                                     34,185
# 16                                     35,905
# 17                                     43,319
# 18                                     38,860
# 19                                     33,596
#
#    2020_Per_capita_personal_income_in_dollars 2019_Percent_change  \
# 0                                      59,510                 3.6
# 1                                      46,479                 3.9
# 2                                      46,814                 3.3
# 3                                      50,953                 2.9
# 4                                      37,850                 4.4
# 5                                      34,300                 4.3
# 6                                      38,808                 3.0
# 7                                      31,944                 4.8
# 8                                      39,988                 6.0
# 9                                      40,195                 3.4
# 10                                     38,508                 6.0
# 11                                     37,869                 2.1
# 12                                     38,778                 4.3
# 13                                     42,231                 2.3
# 14                                     40,822                 4.6
# 15                                     37,179                 3.2
# 16                                     37,734                 0.7
# 17                                     45,262                 2.7
# 18                                     41,941                 3.3
# 19                                     36,908                 3.1
#
#    2020_Percent_change
# 0                  6.2
# 1                  5.6
# 2                  5.5
# 3                  5.6
# 4                  6.4
# 5                  8.8
# 6                  5.0
# 7                 13.5
# 8                  5.0
# 9                  6.6
# 10                 6.6
# 11                 4.1
# 12                 6.3
# 13                 8.0
# 14                10.1
# 15                 8.8
# 16                 5.1
# 17                 4.5
# 18                 7.9
# 19                 9.9

# %%
# make data:
np.random.seed(3)
x = df['GeoName'].to_numpy()[1:50]
y = df['TotalPop'].to_numpy()[1:50]

# %%
# plot
fig, ax = plt.subplots()

ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
sns.scatterplot(x=df.reducetax[51:], y=df.reducetaxOppose[51:])
# Out:
# <AxesSubplot:xlabel='reducetax', ylabel='reducetaxOppose'>
